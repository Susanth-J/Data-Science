# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Iris.csv')
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data = data.drop('Id', 1)
cols = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
data.rename(columns = {cols[0]:0, cols[1]:1, cols[2]:2, cols[3]:3}, inplace=True)
data.loc[::50]
# Out:
# /var/folders/db/95w5g2gn4t7dwj5vmwgl_w880000gn/T/ipykernel_4593/3708628844.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop('Id', 1)
#        0    1    2    3          Species
# 0    5.1  3.5  1.4  0.2      Iris-setosa
# 50   7.0  3.2  4.7  1.4  Iris-versicolor
# 100  6.3  3.3  6.0  2.5   Iris-virginica

# %%
print(data.shape)
data.describe()
# Out:
# (150, 5)
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
# same as data['species'].value_counts()
data.Species.value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
plt.hist(data[0])
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist([data[0], data[1], data[2], data[3]])
# Out:
# (array([[ 0.,  0.,  0.,  0.,  0., 11., 48., 49., 31., 11.],
#         [ 0.,  0., 11., 97., 38.,  4.,  0.,  0.,  0.,  0.],
#         [ 0., 44.,  6.,  1., 10., 34., 30., 20.,  5.,  0.],
#         [50., 52., 45.,  3.,  0.,  0.,  0.,  0.,  0.,  0.]]),
#  array([0.1 , 0.88, 1.66, 2.44, 3.22, 4.  , 4.78, 5.56, 6.34, 7.12, 7.9 ]),
#  <a list of 4 BarContainer objects>)

# %%
plt.hist([data[0], data[1], data[2], data[3]], label=[cols[0],cols[1],cols[2],cols[3]])
plt.legend()

# %%
plt.hist(data[0])
plt.hist(data[1]) 
plt.hist(data[2])
plt.hist(data[3])
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data[0])
plt.hist(data[1], alpha=1) 
plt.hist(data[2], alpha=0.6)
plt.hist(data[3], alpha=0.5)
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots(2, 2, figsize=(8, 4))
ax[0, 0].hist(data[0])
ax[0, 1].hist(data[1])
ax[1, 0].hist(data[2])
ax[1, 1].hist(data[3])
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(8, 6))
ax[0, 0].hist(data[0])
ax[0, 1].hist(data[1])
ax[1, 0].hist(data[2])
ax[1, 1].hist(data[3])
ax[0, 0].set_title(cols[0])
ax[0, 1].set_title(cols[1])
ax[1, 0].set_title(cols[2])
ax[1, 1].set_title(cols[3])
plt.show()

# %%
plt.scatter(
    data[0], 
    data[1],)

# %%
colors = {'Iris-setosa':'red', 'Iris-virginica':'blue', 'Iris-versicolor':'green'}
plt.scatter(
    data[2], 
    data[3], 
    c=data['Species'].map(colors))

# %%
plt.scatter(
    data[0], 
    data[2], 
    c=data['Species'].map(colors))
plt.xlabel(cols[0])
plt.ylabel(cols[2])
# Out:
# Text(0, 0.5, 'PetalLengthCm')

# %%
plt.scatter(
    data[1], 
    data[3], 
    c=data['Species'].map(colors))
plt.xlabel(cols[1])
plt.ylabel(cols[3])
plt.title('Iris Data Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Iris Data Scatter Plot')

# %%
data.corr()
# Out:
# /var/folders/db/95w5g2gn4t7dwj5vmwgl_w880000gn/T/ipykernel_4593/2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#           0         1         2         3
# 0  1.000000 -0.109369  0.871754  0.817954
# 1 -0.109369  1.000000 -0.420516 -0.356544
# 2  0.871754 -0.420516  1.000000  0.962757
# 3  0.817954 -0.356544  0.962757  1.000000

# %%
plt.boxplot([data[0], data[1], data[2], data[3]])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13750ece0>,
#   <matplotlib.lines.Line2D at 0x13750ef80>,
#   <matplotlib.lines.Line2D at 0x13750fe20>,
#   <matplotlib.lines.Line2D at 0x137540100>,
#   <matplotlib.lines.Line2D at 0x1375410c0>,
#   <matplotlib.lines.Line2D at 0x137541360>,
#   <matplotlib.lines.Line2D at 0x137542320>,
#   <matplotlib.lines.Line2D at 0x1375425c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x13750f220>,
#   <matplotlib.lines.Line2D at 0x1374ebe80>,
#   <matplotlib.lines.Line2D at 0x1375403a0>,
#   <matplotlib.lines.Line2D at 0x137540640>,
#   <matplotlib.lines.Line2D at 0x137541600>,
#   <matplotlib.lines.Line2D at 0x1375418a0>,
#   <matplotlib.lines.Line2D at 0x137542860>,
#   <matplotlib.lines.Line2D at 0x137542b00>],
#  'boxes': [<matplotlib.lines.Line2D at 0x13750ce20>,
#   <matplotlib.lines.Line2D at 0x13750fb80>,
#   <matplotlib.lines.Line2D at 0x137540e20>,
#   <matplotlib.lines.Line2D at 0x137542080>],
#  'medians': [<matplotlib.lines.Line2D at 0x13750f640>,
#   <matplotlib.lines.Line2D at 0x1375408e0>,
#   <matplotlib.lines.Line2D at 0x137541b40>,
#   <matplotlib.lines.Line2D at 0x137542da0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13750f8e0>,
#   <matplotlib.lines.Line2D at 0x137540b80>,
#   <matplotlib.lines.Line2D at 0x137541de0>,
#   <matplotlib.lines.Line2D at 0x137543040>],
#  'means': []}

# %%
data.boxplot(column=[0], by=['Species'])
# Out:
# <Axes: title={'center': '0'}, xlabel='[Species]'>

# %%
fig, ax = plt.subplots(2, 2, figsize=(8, 6))
A = [data[0][data.Species == 'Iris-setosa'], data[0][data.Species == 'Iris-virginica'], data[0][data.Species == 'Iris-versicolor']]
B = [data[1][data.Species == 'Iris-setosa'], data[1][data.Species == 'Iris-virginica'], data[1][data.Species == 'Iris-versicolor']]
C = [data[2][data.Species == 'Iris-setosa'], data[2][data.Species == 'Iris-virginica'], data[2][data.Species == 'Iris-versicolor']]
D = [data[3][data.Species == 'Iris-setosa'], data[3][data.Species == 'Iris-virginica'], data[3][data.Species == 'Iris-versicolor']]

ax[0, 0].boxplot(A, widths = 0.7)
ax[0, 0].set_title(cols[0])
ax[0, 1].boxplot(B, widths = 0.7)
ax[0, 1].set_title(cols[1])
ax[1, 0].boxplot(C, widths = 0.7)
ax[1, 0].set_title(cols[2])
ax[1, 1].boxplot(D, widths = 0.7)
ax[1, 1].set_title(cols[3])
# Out:
# Text(0.5, 1.0, 'PetalWidthCm')

# %%
def set_color(bp):
    plt.setp(bp['boxes'][0], color='blue')
    plt.setp(bp['boxes'][1], color='red')
    plt.setp(bp['boxes'][2], color='green')

A = [data[0][data.Species == 'Iris-setosa'], data[0][data.Species == 'Iris-virginica'], data[0][data.Species == 'Iris-versicolor']]
B = [data[1][data.Species == 'Iris-setosa'], data[1][data.Species == 'Iris-virginica'], data[1][data.Species == 'Iris-versicolor']]
C = [data[2][data.Species == 'Iris-setosa'], data[2][data.Species == 'Iris-virginica'], data[2][data.Species == 'Iris-versicolor']]
D = [data[3][data.Species == 'Iris-setosa'], data[3][data.Species == 'Iris-virginica'], data[3][data.Species == 'Iris-versicolor']]

# add this to remove outlier symbols: 0, '',
bp = plt.boxplot(A, 0, '', positions = [1, 2, 3], widths = 0.7)
set_color(bp)
bp = plt.boxplot(B, 0, '', positions = [5, 6, 7], widths = 0.7)
set_color(bp)
bp = plt.boxplot(C, 0, '', positions = [9, 10, 11], widths = 0.7)
set_color(bp)
bp = plt.boxplot(D, 0, '', positions = [13, 14, 15], widths = 0.7)
set_color(bp)

ax = plt.axes()
ax.set_xticks([2, 6, 10, 14])
ax.set_xticklabels(cols)

plt.show()
